# %%
### 
# Travel to Root required due to ipynb's limitations'
###
import os
from pathlib import Path
# print(os.getcwd())

p = Path.cwd()
print(p)

while True:
    if (p / 'venv').exists():
        print('we have reached root cwd')
        break
    if p == p.parent:
        raise FileNotFoundError(f"venv is missing at the top level, cannot confirm this is root. exit")
    p = p.parent

MACROECONS_ROOT = p
print(MACROECONS_ROOT)
# Out:
# /Users/murftech/Dropbox/Datarepo/macroecons/modules/hdb_assess
# we have reached root cwd
# /Users/murftech/Dropbox/Datarepo/macroecons

# %%
###################################
# imports
###################################

from polars import col, concat, lit, when
import polars as pl

import sys
sys.path.append('/Users/murftech/Dropbox/Datarepo/macroecons/modules/hdb_assess')


from modules.hdb_assess.hdb_helpers import fetch_hdb_data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[24], line 12
#       8 import sys
#       9 sys.path.append('/Users/murftech/Dropbox/Datarepo/macroecons/modules/hdb_assess')
# ---> 12 from modules.hdb_assess.hdb_helpers import fetch_hdb_data
#
# ModuleNotFoundError: No module named 'modules'

# %%
# VALIDATE = on/off
# VALIDATE = 'off'
VALIDATE = 'off'

# %%
# view variables

hdbdata;
